# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import os

# %%
# Create dataset
def raw_df_generator(year):
    file_list = os.listdir(r'mta_data/%s'%str(year))
    df = pd.read_csv(r'mta_data/%s/%s'%(str(year), file_list[0]))

    for i in range (1,len(file_list)):
        df = pd.concat([df, pd.read_csv(r'mta_data/%s/%s'%(str(year), file_list[i]))], axis = 0)

    return df

# %%
raw_df_2022 = raw_df_generator(2022)

# %%
raw_df_2022.head(100)
# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0   A002  R051  02-00-00   59 ST  NQR456W      BMT  02/26/2022  03:00:00
# 1   A002  R051  02-00-00   59 ST  NQR456W      BMT  02/26/2022  07:00:00
# 2   A002  R051  02-00-00   59 ST  NQR456W      BMT  02/26/2022  11:00:00
# 3   A002  R051  02-00-00   59 ST  NQR456W      BMT  02/26/2022  15:00:00
# 4   A002  R051  02-00-00   59 ST  NQR456W      BMT  02/26/2022  19:00:00
# ..   ...   ...       ...     ...      ...      ...         ...       ...
# 95  A002  R051  02-03-00   59 ST  NQR456W      BMT  02/27/2022  23:00:00
# 96  A002  R051  02-03-00   59 ST  NQR456W      BMT  02/28/2022  03:00:00
# 97  A002  R051  02-03-00   59 ST  NQR456W      BMT  02/28/2022  07:00:00
# 98  A002  R051  02-03-00   59 ST  NQR456W      BMT  02/28/2022  11:00:00
# 99  A002  R051  02-03-00   59 ST  NQR456W      BMT  02/28/2022  15:00:00
#
#        DESC  ENTRIES  \
# 0   REGULAR  7689737
# 1   REGULAR  7689741
# 2   REGULAR  7689758
# ...

# %%
raw_df_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2739787 entries, 0 to 211706
# Data columns (total 11 columns):
#  #   Column                                                                Dtype
# ---  ------                                                                -----
#  0   C/A                                                                   object
#  1   UNIT                                                                  object
#  2   SCP                                                                   object
#  3   STATION                                                               object
#  4   LINENAME                                                              object
#  5   DIVISION                                                              object
#  6   DATE                                                                  object
#  7   TIME                                                                  object
# ...

# %%
raw_df_2022.describe()
# Out:
#             ENTRIES  \
# count  2.739787e+06
# mean   4.290863e+07
# std    2.234785e+08
# min    0.000000e+00
# 25%    2.490380e+05
# 50%    1.354802e+06
# 75%    5.967922e+06
# max    2.147319e+09
#
#        EXITS
# count                                       2.739787e+06
# mean                                        3.453942e+07
# std                                         1.970575e+08
# min                                         0.000000e+00
# 25%                                         1.325570e+05
# 50%                                         8.856720e+05
# 75%                                         3.975252e+06
# max                                         2.122443e+09

# %%
raw_df_2022["Entry"] = raw_df_2022.groupby('STATION')["ENTRIES"].diff()

# %%
raw_df_2022["Exit"] = raw_df_2022.groupby('STATION')["EXITS                                                               "].diff()

# %%
grouped_station = raw_df_2022.groupby('STATION')

# %%
grouped_station.first()
# Out:
#                   C/A  UNIT       SCP LINENAME DIVISION        DATE      TIME  \
# STATION
# 1 AV             H007  R248  00-00-00        L      BMT  02/26/2022  03:00:00
# 103 ST           N037  R314  00-00-00       BC      IND  02/26/2022  00:00:00
# 103 ST-CORONA    R529  R208  00-00-00        7      IRT  02/26/2022  03:00:00
# 104 ST           J034  R007  00-00-00       JZ      BMT  02/26/2022  03:00:00
# 110 ST           R253  R181  00-00-00        6      IRT  02/26/2022  03:00:00
# ...               ...   ...       ...      ...      ...         ...       ...
# WOODLAWN         R294  R052  00-00-00        4      IRT  02/26/2022  03:00:00
# WORLD TRADE CTR  N094  R029  01-00-00    ACE23      IND  02/26/2022  03:00:00
# WTC-CORTLANDT    R106  R305  01-00-00        1      IRT  02/26/2022  00:00:00
# YORK ST          N530  R301  00-00-00        F      IND  02/26/2022  00:00:00
# ZEREGA AV        R419  R326  00-00-00        6      IRT  02/26/2022  00:00:00
#
# ...

# %%
raw_df_2022.head(50000).to_excel('2022.xlsx')

# %%
# Out:
# 379

# %%
print(f'Number of stations: { raw_df_2022["STATION"].nunique()}')
# Out:
# Number of stations: 379

# %%
wiki_df = pd.read_html("https://en.wikipedia.org/wiki/List_of_New_York_City_Subway_stations")

# %%
wiki_df[4]
# Out:
#                                       Station complex  \
# 0                          Fourth Avenue/Ninth Street
# 1                          Fourth Avenue/Ninth Street
# 2                            14th Street/Sixth Avenue
# 3                            14th Street/Sixth Avenue
# 4                            14th Street/Sixth Avenue
# 5                           14th Street/Eighth Avenue
# 6                           14th Street/Eighth Avenue
# 7                            14th Street–Union Square
# 8                            14th Street–Union Square
# 9                            14th Street–Union Square
# 10               42nd Street–Bryant Park/Fifth Avenue
# 11               42nd Street–Bryant Park/Fifth Avenue
# 12                     62nd Street/New Utrecht Avenue
# 13                     62nd Street/New Utrecht Avenue
# 14                          Borough Hall/Court Street
# 15                          Borough Hall/Court Street
# ...
